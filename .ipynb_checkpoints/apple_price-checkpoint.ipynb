# %%
import pandas as pd
import numpy as np
import datetime

# 그래프 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# 폰트
import platform

if platform.system() == 'Darwin':    # 맥
    font_name = 'AppleGothic'
elif platform.system() == 'Linux':   # 리눅스
    font_name = 'NanumGothic'
elif platform.system() == 'Windows': # 윈도우
    font_name = 'Malgun Gothic'
else:
    print('알수없는 시스템. 미적용')

plt.rc('font', family=font_name)

# %%
#데이터를 불러온다
df = pd.read_csv('./data/maindata_four.csv', encoding='utf-8')
df1 = pd.read_csv('./data/typhoon.csv', encoding='euc-kr')
df1 = df1.iloc[:,:3]

# %%
#태풍이 온 날은 40000을 준다
df.태풍.replace('o',40000,inplace= True)

# %%
#태풍이 안 온날은 0을 준다
df.태풍.replace('x',0,inplace= True)

# %%
#데이터 형태 확인
df.shape
# Out:
# (993, 19)

# %%
#컬럼 확인
df.columns
# Out:
# Index(['날짜', 'avg_moo', 'avgY_moo', 'avg_baechoo', 'avgY_baechoo', 'avg_apple',
#        'avgY_apple', 'avg_scallion', 'avgY_scallion', '현재일기', '현재기온', '이슬점온도',
#        '체감온도', '강수량', '습도', '풍향', '풍속', '해면기압', '태풍'],
#       dtype='object')

# %%
# 중복값 확인 
# df.태풍.duplicated()
#벨류 개수 확인
df.태풍.value_counts()
# Out:
# x    929
# o     64
# Name: 태풍, dtype: int64

# %%
#자료형 확인
df.dtypes
# Out:
# 날짜                object
# avg_moo            int64
# avgY_moo           int64
# avg_baechoo        int64
# avgY_baechoo       int64
# avg_apple          int64
# avgY_apple         int64
# avg_scallion       int64
# avgY_scallion      int64
# 현재일기              object
# 현재기온             float64
# 이슬점온도            float64
# 체감온도             float64
# 강수량              float64
# 습도               float64
# 풍향                object
# 풍속               float64
# 해면기압             float64
# 태풍                 int64
# dtype: object

# %% [markdown]
# # de이터 시각화해서 확인

# %%
plot = plt.figure()
axes = plot.add_subplot(1,1,1)

# %%
plot = plt.figure()
axes = plot.add_subplot(1,1,1)
axes.plot(df['avg_apple']) # 파랑색
axes.plot(df['태풍']) # 노랑색 (0아니면 40000)

# %%
# 순수 태풍 
plot = plt.figure()
axes = plot.add_subplot(1,1,1)
# axes.plot(df['날짜'])
axes.plot(df['태풍'])

# %%
#날짜를 - 기준으로 나눠서 담고 반복문을 수행한 결과를 i에 담는다(년)
li_year = [ i[0] for i in df.날짜.str.split('-') ]
##날짜를 - 기준으로 나눠서 담고 반복문을 수행한 결과를 i에 담는다(월)
li_month = [ i[1] for i in df.날짜.str.split('-') ]

idx_year = list()

for i in range(len(li_year)):
    idx.append(i) #append 리스트에 붙인다
    if li_year[i] == "2017":
#         if li_month[i] == "01":
            idx_year.append(i)
            
# each_ye_mon = main_data.iloc[idx]
print(idx_year)

# %%
# li_year = [ i[0] for i in df.날짜.str.split('-') ]
# 위랑 같음 차이는 리스트
tmp = list()
for i in df.날짜.str.split('-'):
#    i =[2015,03,01]
    print(i[0])
# Out:
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# ...

# %%
# 연도 추출 코드

li_year = [ i[0] for i in df.날짜.str.split('-') ]
li_month = [ i[1] for i in df.날짜.str.split('-') ]

idx_year = list()

for i in range(len(li_year)):
#     idx_.append(i)
    if li_year[i] ==  '2017':
        idx_year.append(i)
        
print(idx_year)
# Out:
# [411, 412, 413, 414, 415, 416, 417, 418, 419, 420, 421, 422, 423, 424, 425, 426, 427, 428, 429, 430, 431, 432, 433, 434, 435, 436, 437, 438, 439, 440, 441, 442, 443, 444, 445, 446, 447, 448, 449, 450, 451, 452, 453, 454, 455, 456, 457, 458, 459, 460, 461, 462, 463, 464, 465, 466, 467, 468, 469, 470, 471, 472, 473, 474, 475, 476, 477, 478, 479, 480, 481, 482, 483, 484, 485, 486, 487, 488, 489, 490, 491, 492, 493, 494, 495, 496, 497, 498, 499, 500, 501, 502, 503, 504, 505, 506, 507, 508, 509, 510, 511, 512, 513, 514, 515, 516, 517, 518, 519, 520, 521, 522, 523, 524, 525, 526, 527, 528, 529, 530, 531, 532, 533, 534, 535, 536, 537, 538, 539, 540, 541, 542, 543, 544, 545, 546, 547, 548, 549, 550, 551, 552, 553, 554, 555, 556, 557, 558, 559, 560, 561, 562, 563, 564, 565, 566, 567, 568, 569, 570, 571, 572, 573, 574, 575, 576, 577, 578, 579, 580, 581, 582, 583, 584, 585, 586, 587, 588, 589, 590, 591, 592, 593, 594, 595, 596, 597, 598, 599, 600, 601, 602, 603, 604, 605, 606, 607, 608, 609, 61
# ...

# %%
df.iloc[idx_year]
# Out:
#              날짜  avg_moo  avgY_moo  avg_baechoo  avgY_baechoo  avg_apple  \
# 411  2017-01-03     3085      1383         4355          2081      18251
# 412  2017-01-04     3055      1334         4380          2870      18251
# 413  2017-01-05     3085      1308         4379          3248      18479
# 414  2017-01-06     3096      1303         4354          2893      18483
# 415  2017-01-09     3072      1284         4279          2033      18729
# ..          ...      ...       ...          ...           ...        ...
# 608  2017-12-22     1632      1875         2800          2595      20696
# 609  2017-12-26     1645      1743         2823          3037      20600
# 610  2017-12-27     1637      1720         2865          3038      20542
# 611  2017-12-28     1568      1751         2884          3082      20576
# 612  2017-12-29     1578      1649         2901          3086      20384
#
#      avgY_apple  avg_scallion  avgY_scallion 현재일기  현재기온  이슬점온도  체감온도  강수량  \
# ...

# %%
# # 월 

# li_year = [ i[0] for i in df.날짜.str.split('-') ]
# li_month = [ i[1] for i in df.날짜.str.split('-') ]

# idx = list()

# for i in range(len(li_year)):
#     if li_year[i] == "2017":
#         if li_month[i] == "01":
#             idx.append(i)
            
# # each_ye_mon = main_data.iloc[idx]
# print(idx)
# Out:
# [411, 412, 413, 414, 415, 416, 417, 418, 419, 420, 421, 422, 423, 424, 425, 426, 427, 428, 429]

# %%
test = df.iloc[idx_year,:]

# %%
ax = plt.subplots() 
ax = sns.distplot(test['avg_apple'], hist=False)

# %%
test.shape
# Out:
# (202, 19)

# %%
#그래프 그리기
#월별

grp = plt.plot(test.날짜[idx_year], test.avg_apple[idx_year])

# %%
# df_test = test.iloc[:]


plot = plt.figure()
axes = plot.add_subplot(1,1,1)
axes.plot(test['avg_apple'])
axes.plot(test['태풍'])

# %%
# 1년 2017 년 한해 
ax = plt.subplot()
ax = sns.barplot(x='날짜',y='avg_apple', data = test)

# %%
df.columns
# Out:
# Index(['날짜', 'avg_moo', 'avgY_moo', 'avg_baechoo', 'avgY_baechoo', 'avg_apple',
#        'avgY_apple', 'avg_scallion', 'avgY_scallion', '현재일기', '현재기온', '이슬점온도',
#        '체감온도', '강수량', '습도', '풍향', '풍속', '해면기압', '태풍'],
#       dtype='object')

# %% [markdown]
# # 상관계수

# %%
df = pd.read_csv('./data/maindata_four.csv', encoding='utf-8')
df1 = pd.read_csv('./data/typhoon.csv', encoding='euc-kr')
df1 = df1.iloc[:,:3]

# %%
df.columns
# Out:
# Index(['날짜', 'avg_moo', 'avgY_moo', 'avg_baechoo', 'avgY_baechoo', 'avg_apple',
#        'avgY_apple', 'avg_scallion', 'avgY_scallion', '현재일기', '현재기온', '이슬점온도',
#        '체감온도', '강수량', '습도', '풍향', '풍속', '해면기압', '태풍'],
#       dtype='object')

# %%
heatmap_data = df[[ 'avg_moo', 'avgY_moo', 'avg_baechoo', 'avgY_baechoo', 'avg_apple',
       'avgY_apple', 'avg_scallion', 'avgY_scallion',  '현재기온', '이슬점온도',
       '체감온도', '강수량', '습도', '풍속', '해면기압']]

colormap = plt.cm.RdBu 
plt.figure(figsize=(14, 15))
plt.title('test', y=1.05, size=15)

sns.heatmap(heatmap_data.astype(float).corr(), linewidths=0.1, vmax=1.0,
           square=True, cmap=colormap, linecolor='white', annot=True, annot_kws={"size": 16})

# %%
df.avgY_apple
# Out:
# 0      22826
# 1      22882
# 2      22949
# 3      22809
# 4      22827
#        ...
# 988    19021
# 989    19055
# 990    19115
# 991    19290
# 992    19119
# Name: avgY_apple, Length: 993, dtype: int64

# %%
# df.태풍 
# df['태풍']

# %% [markdown]
# # 결측치 제거

# %%
#결측치 값에 0 넣기
df.fillna(0)
#df.replace('NaN',0 ,)
# Out:
#              날짜  avg_moo  avgY_moo  avg_baechoo  avgY_baechoo  avg_apple  \
# 0    2015-01-05     1287      1449         1957          3466      21350
# 1    2015-01-06     1303      1432         1980          3481      21717
# 2    2015-01-07     1277      1411         1957          2670      21944
# 3    2015-01-08     1352      1407         1959          2607      21442
# 4    2015-01-09     1333      1403         1936          2597      21476
# ..          ...      ...       ...          ...           ...        ...
# 988  2019-12-24     3073      1618         4575          2924      18135
# 989  2019-12-26     3068      1596         4495          2924      18293
# 990  2019-12-27     3022      1582         4474          2947      18293
# 991  2019-12-30     2987      1480         4502          3076      18328
# 992  2019-12-31     3023      1473         4547          3105      18328
#
#      avgY_apple  avg_scallion  avgY_scallion 현재일기  현재기온  이슬점온도  체감온도   강수량  \
# ...

# %% [markdown]
# # 강수량 이상치 없애기 (이상치 없음)

# %% [markdown]
# ### 강수랑 >= 140 제거 (이상치)

# %%
# 
# # df[df.강수량>= 140]
# df.drop(index= df[df.강수량>= 140].index, inplace= True)
# df[df.강수량>= 140]
# Out:
# Empty DataFrame
# Columns: [날짜, avg_moo, avgY_moo, avg_baechoo, avgY_baechoo, avg_apple, avgY_apple, avg_scallion, avgY_scallion, 현재일기, 현재기온, 이슬점온도, 체감온도, 강수량, 습도, 풍향, 풍속, 해면기압, 태풍]
# Index: []

# %%
df_test[df_test.강수량 > 0].index
# Out:
# Int64Index([  1,   7,   8,  13,  15,  22,  30,  38,  49,  50,
#             ...
#             932, 941, 942, 945, 946, 947, 949, 950, 963, 991],
#            dtype='int64', length=207)

# %%
df_test = df.iloc[:,:]
df_test[df_test.강수량 == 0].index

df_test.drop(index=df_test[df_test.강수량 == 0].index, inplace=True)

# %%
df.강수량.value_counts()
# Out:
# 0.1     16
# 0.5     16
# 1.0     13
# 0.2     11
# 3.5     10
#         ..
# 3.1      1
# 3.8      1
# 6.1      1
# 31.4     1
# 45.5     1
# Name: 강수량, Length: 90, dtype: int64

# %% [markdown]
# # 산점도
# - 이슬점 온도
# - 평균 온도
# - 체감 온도
# - 습도

# %%
# 데이터 세트에서 쌍별 관계를 나타내는 서브 플롯 그리드
pair_grid = sns.PairGrid(df) 
pair_grid = pair_grid.map_upper(sns.regplot) 
pair_grid = pair_grid.map_lower(sns.kdeplot) 
pair_grid = pair_grid.map_diag(sns.distplot, rug=True) 

plt.show()
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\matplotlib\contour.py:1520: UserWarning: Warning: converting a masked element to nan.
#   self.zmax = float(z.max())
# C:\Users\admin\Anaconda3\lib\site-packages\matplotlib\contour.py:1521: UserWarning: Warning: converting a masked element to nan.
#   self.zmin = float(z.min())
# C:\Users\admin\Anaconda3\lib\site-packages\matplotlib\contour.py:1169: RuntimeWarning: invalid value encountered in less
#   under = np.nonzero(lev < self.zmin)[0]
# C:\Users\admin\Anaconda3\lib\site-packages\matplotlib\contour.py:1171: RuntimeWarning: invalid value encountered in greater
#   over = np.nonzero(lev > self.zmax)[0]
# C:\Users\admin\Anaconda3\lib\site-packages\matplotlib\contour.py:1200: RuntimeWarning: invalid value encountered in greater
#   inside = (self.levels > self.zmin) & (self.levels < self.zmax)
# C:\Users\admin\Anaconda3\lib\site-packages\matplotlib\contour.py:1200: RuntimeWarning: invalid value encountered in less
# ...

# %%
df.columns
# Out:
# Index(['날짜', 'avg_moo', 'avgY_moo', 'avg_baechoo', 'avgY_baechoo', 'avg_apple',
#        'avgY_apple', 'avg_scallion', 'avgY_scallion', '현재일기', '현재기온', '이슬점온도',
#        '체감온도', '강수량', '습도', '풍향', '풍속', '해면기압', '태풍'],
#       dtype='object')

# %%
df.loc[:,['avg_apple','avgY_apple', '현재기온', '이슬점온도',
       '체감온도', '강수량', '습도', '풍속', '해면기압']]
# Out:
#      avg_apple  avgY_apple  현재기온  이슬점온도  체감온도   강수량    습도    풍속    해면기압
# 1        21717       22882   9.1  -16.2   6.7  11.5  15.0  15.8  1011.3
# 7        21302       23797   5.3   -1.4   3.9   0.5  62.0   6.5  1025.3
# 8        21208       23878   9.3   -1.4   6.6   0.5  47.0  18.7  1020.1
# 13       21743       25114   6.8   -0.4   4.3   2.5  60.0  12.6  1015.9
# 15       21955       24844  10.0    7.7   8.4   6.0  86.0  11.5  1016.5
# ..         ...         ...   ...    ...   ...   ...   ...   ...     ...
# 973      17693       19310   NaN    NaN   NaN   NaN   NaN   NaN     NaN
# 974      17710       19004   NaN    NaN   NaN   NaN   NaN   NaN     NaN
# 975      17582       18967   NaN    NaN   NaN   NaN   NaN   NaN     NaN
# 976      17540       19050   NaN    NaN   NaN   NaN   NaN   NaN     NaN
# 991      18328       19290  13.3    7.5  12.5   1.0  68.0  10.4  1019.7
#
# [215 rows x 9 columns]

# %%
df_check = df.loc[:40,['avg_apple','avgY_apple', '현재기온', '이슬점온도',
       '체감온도', '강수량', '습도', '풍속', '해면기압']]

# %%
#그래프 종합 => 관계 그래프
fig = sns.pairplot(df_check)

# %%
df.shape
# Out:
# (215, 19)

# %% [markdown]
# # 해야하는거
#
# - 태풍의 영향을 실제 태풍이 미치는 기간을 찾아야 한다.
#    - 보고
# - 상관관계
#     - 각각의 변수를 확인해서 가격에 영향을 미치는 영향

# %%
import pandas as pd
import numpy as np
import datetime

# 그래프 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# 폰트
import platform

if platform.system() == 'Darwin':    # 맥
    font_name = 'AppleGothic'
elif platform.system() == 'Linux':   # 리눅스
    font_name = 'NanumGothic'
elif platform.system() == 'Windows': # 윈도우
    font_name = 'Malgun Gothic'
else:
    print('알수없는 시스템. 미적용')

plt.rc('font', family=font_name)

# %%
df = pd.read_csv('./data/maindata.csv', encoding='utf-8')
df1 = pd.read_csv('./data/typhoon.csv', encoding='euc-kr')
df1 = df1.iloc[:,:3]

# %%
df.태풍.replace('o',4000,inplace= True)

# %%
df.태풍.replace('x',0,inplace= True)

# %%
df.shape
# Out:
# (1188, 13)

# %%
df.columns
# Out:
# Index(['날짜', '평균', '평년', '현재일기', '현재기온', '이슬점온도', '체감온도', '강수량', '습도', '풍향',
#        '풍속', '해면기압', '태풍'],
#       dtype='object')

# %%
# 중복값 확인 
# df.태풍.duplicated()
df.태풍.value_counts()
# Out:
# 0       1092
# 4000      96
# Name: 태풍, dtype: int64

# %%
df.dtypes
# Out:
# 날짜        object
# 평균         int64
# 평년         int64
# 현재일기      object
# 현재기온     float64
# 이슬점온도    float64
# 체감온도     float64
# 강수량      float64
# 습도       float64
# 풍향        object
# 풍속       float64
# 해면기압     float64
# 태풍         int64
# dtype: object

# %%
df_test = df.loc[0:300]
print(df_test.iloc[0,[0]])
print(df_test.iloc[-1,[0]])
# Out:
# 날짜    2015-01-02
# Name: 0, dtype: object
# 날짜    2016-03-22
# Name: 300, dtype: object

# %%
ax = plt.subplot()
# ax = sns.distplot(df['평균'])
ax = sns.distplot(df_test['평년'])
plt.figure(figsize=(100, 30))
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\admin\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
df_test = df.iloc[:]


plot = plt.figure()
axes = plot.add_subplot(1,1,1)
axes.plot(df['평균'])
axes.plot(df['태풍'])

# %%
date_df = df.iloc[:,:1]

# %%
df_test = df.iloc[:]


plot = plt.figure()
axes = plot.add_subplot(1,1,1)
# axes.plot(df['날짜'])
axes.plot(df['태풍'])

# %%
li_year = [ i[0] for i in df.날짜.str.split('-') ]
li_month = [ i[1] for i in df.날짜.str.split('-') ]

# %%
li_year = [ i[0] for i in df.날짜.str.split('-') ]
li_month = [ i[1] for i in df.날짜.str.split('-') ]

idx_year = list()

for i in range(len(li_year)):
    idx.append(i)
    if li_year[i] == "2017":
#         if li_month[i] == "01":
            idx_year.append(i)
            
# each_ye_mon = main_data.iloc[idx]
print(idx_year)
# Out:
# [494, 495, 496, 497, 498, 499, 500, 501, 502, 503, 504, 505, 506, 507, 508, 509, 510, 511, 512, 513, 514, 515, 516, 517, 518, 519, 520, 521, 522, 523, 524, 525, 526, 527, 528, 529, 530, 531, 532, 533, 534, 535, 536, 537, 538, 539, 540, 541, 542, 543, 544, 545, 546, 547, 548, 549, 550, 551, 552, 553, 554, 555, 556, 557, 558, 559, 560, 561, 562, 563, 564, 565, 566, 567, 568, 569, 570, 571, 572, 573, 574, 575, 576, 577, 578, 579, 580, 581, 582, 583, 584, 585, 586, 587, 588, 589, 590, 591, 592, 593, 594, 595, 596, 597, 598, 599, 600, 601, 602, 603, 604, 605, 606, 607, 608, 609, 610, 611, 612, 613, 614, 615, 616, 617, 618, 619, 620, 621, 622, 623, 624, 625, 626, 627, 628, 629, 630, 631, 632, 633, 634, 635, 636, 637, 638, 639, 640, 641, 642, 643, 644, 645, 646, 647, 648, 649, 650, 651, 652, 653, 654, 655, 656, 657, 658, 659, 660, 661, 662, 663, 664, 665, 666, 667, 668, 669, 670, 671, 672, 673, 674, 675, 676, 677, 678, 679, 680, 681, 682, 683, 684, 685, 686, 687, 688, 689, 690, 691, 692, 69
# ...

# %%
# # 월 

# li_year = [ i[0] for i in df.날짜.str.split('-') ]
# li_month = [ i[1] for i in df.날짜.str.split('-') ]

# idx = list()

# for i in range(len(li_year)):
#     if li_year[i] == "2017":
#         if li_month[i] == "01":
#             idx.append(i)
            
# # each_ye_mon = main_data.iloc[idx]
# print(idx)
# Out:
# [494, 495, 496, 497, 498, 499, 500, 501, 502, 503, 504, 505, 506, 507, 508, 509, 510, 511, 512, 513]

# %%
test = df.iloc[idx_year,:]

# %%
# idx = list()

# for i in range(len(li_year)):
#     if li_year[i] == "2017":
#         if li_month[i] == "01":
#             idx.append(i)
# print(idx)

# %%
# ax = plt.subplots() 
# ax = sns.distplot(test['평균'], hist=False)
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
test.shape
# Out:
# (243, 13)

# %%
# 그래프 그리기
# # 월별 
grp = plt.plot(test.날짜[idx_year],test.평균[idx_year])
grp

# %%
# a = get_year(2017)
# # fig = sns.pairplot(a)

# hexbin = sns.jointplot(x='태풍', y='평균', data=a)

# axes.hist(a['total_bill'],bins=10)

# %%
# df_test = test.iloc[:]


plot = plt.figure()
axes = plot.add_subplot(1,1,1)
axes.plot(test['평균'])
axes.plot(test['태풍'])

# %%
# 1년 2017 년 한해 
ax = plt.subplot()
ax = sns.barplot(x='날짜',y='평균', data = test)

# %%
df.columns
# Out:
# Index(['날짜', '평균', '평년', '현재일기', '현재기온', '이슬점온도', '체감온도', '강수량', '습도', '풍향',
#        '풍속', '해면기압', '태풍'],
#       dtype='object')

# %% [markdown]
# # 상관계수

# %%
df = pd.read_csv('./data/maindata.csv', encoding='utf-8')
df1 = pd.read_csv('./data/typhoon.csv', encoding='euc-kr')
df1 = df1.iloc[:,:3]

# %%
df.columns
# Out:
# Index(['날짜', '평균', '평년', '현재일기', '현재기온', '이슬점온도', '체감온도', '강수량', '습도', '풍향',
#        '풍속', '해면기압', 'tor_o', 'tor_x'],
#       dtype='object')

# %%
heatmap_data  = df[['평균','현재기온', '이슬점온도', '체감온도', '강수량', '습도',
       '풍속', '해면기압', '태풍']]

colormap = plt.cm.RdBu 
plt.figure(figsize=(14, 15))
plt.title('test', y=1.05, size=15)

sns.heatmap(heatmap_data.astype(float).corr(), linewidths=0.1, vmax=1.0,
           square=True, cmap=colormap, linecolor='white', annot=True, annot_kws={"size": 16})

# %% [markdown]
# ##  결측치 제거

# %%
# 결측 
df.fillna(0)
# df.replace('NaN',0 ,)
# Out:
#               날짜    평균    평년 현재일기  현재기온  이슬점온도  체감온도   강수량    습도   풍향    풍속  \
# 0     2015-01-02  1287  1561    -   2.1  -15.4  -2.3   0.0  26.0   북서  17.6
# 1     2015-01-05  1287  1449    -  10.4   -3.3  10.4   0.0  38.0  서북서   2.9
# 2     2015-01-06  1303  1432    -   9.1  -16.2   6.7  11.5  15.0   북서  15.8
# 3     2015-01-07  1277  1411    -   2.5  -28.5  -1.6   0.0   8.0   북서  16.9
# 4     2015-01-08  1352  1407    -   3.3  -19.4  -0.1   0.0  17.0   북서  13.7
# 5     2015-01-09  1333  1403    -   5.1  -12.4   1.6   0.0  27.0   북서  16.6
# 6     2015-01-12  1329  1352    -   4.9  -14.0   2.0   0.0  24.0  서북서  13.0
# 7     2015-01-13  1329  1340    -   9.1   -8.9   7.7   0.0  27.0  서남서   9.0
# 8     2015-01-14  1329  1326    -   5.3   -1.4   3.9   0.5  62.0  서북서   6.5
# 9     2015-01-15  1262  1321    -   9.3   -1.4   6.6   0.5  47.0   북서  18.7
# 10    2015-01-16  1258  1314    -   8.5   -5.3   5.7   0.0  37.0   북서  18.0
# ...

# %% [markdown]
# # 강수량 이상치 없애기

# %% [markdown]
# ### 강수량 >= 140 제거 ( 이상치 )

# %%
# df[df.강수량>= 140]
df.drop(index= df[df.강수량>= 70].index, inplace= True)
df[df.강수량>= 70]
# Out:
# Empty DataFrame
# Columns: [날짜, 평균, 평년, 현재일기, 현재기온, 이슬점온도, 체감온도, 강수량, 습도, 풍향, 풍속, 해면기압, 태풍]
# Index: []

# %%
# df[df.강수량>= 140]
df.drop(index= df[df.강수량>= 140].index, inplace= True)
df[df.강수량>= 140]
# Out:
# Empty DataFrame
# Columns: [날짜, 평균, 평년, 현재일기, 현재기온, 이슬점온도, 체감온도, 강수량, 습도, 풍향, 풍속, 해면기압, 태풍]
# Index: []

# %%
# df.iloc[:,:]

# %%
df_test = df.iloc[:,:]
df_test[df_test.강수량 == 0].index


df_test.drop(index=df_test[df_test.강수량 == 0].index, inplace= True)

# %%
df.강수량.value_counts() 
# df[df.강수량 <=140 ].value_counts()

# %%
# heatmap_data  = df[['평균', '평년','현재기온', '이슬점온도', '체감온도', '강수량', '습도',
#        '풍속', '해면기압', '태풍']]

# colormap = plt.cm.RdBu 
# plt.figure(figsize=(14, 15))
# plt.title('test', y=1.05, size=15)

# sns.heatmap(heatmap_data.astype(float).corr(), linewidths=0.1, vmax=1.0,
#            square=True, cmap=colormap, linecolor='white', annot=True, annot_kws={"size": 16})

# %% [markdown]
# ## 산점도
# - 이슬점온도
# - 평균온도
# - 체감온도
# - 습도

# %%
pair_grid = sns.PairGrid(df) 
pair_grid = pair_grid.map_upper(sns.regplot) 
pair_grid = pair_grid.map_lower(sns.kdeplot) 
pair_grid = pair_grid.map_diag(sns.distplot, rug=True) 

plt.show()
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\admin\Anaconda3\lib\site-packages\matplotlib\contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# C:\Users\admin\Anaconda3\lib\site-packages\matplotlib\contour.py:1480: UserWarning: Warning: converting a masked element to nan.
#   self.zmax = float(z.max())
# C:\Users\admin\Anaconda3\lib\site-packages\matplotlib\contour.py:1481: UserWarning: Warning: converting a masked element to nan.
#   self.zmin = float(z.min())
# ...

# %%
df_test.shape
# Out:
# (252, 13)

# %%
# fig = sns.pairplot(df,hue='태풍')
# 색상 추가 
# scatter = sns.lmplot(x='평균',y='이슬점온도',data=df, hue=['태풍'], fit_reg=False)
# plt.show()

# %% [markdown]
# # 세부 산점도

# %%
# hexbin  - 강수량 
fig, ax = plt.subplots()
ax = df_test.plot.hexbin(x='평균', y='강수량', gridsize=10,ax=ax)

# %%
# 산점도  - 강수량 
scatter_plot = plt.figure()
axes = scatter_plot.add_subplot(1,1,1)
axes.scatter(df_test['평균'],df_test['강수량'])

# %%
# 산점도  - 강수량 
scatter_plot = plt.figure()
axes = scatter_plot.add_subplot(1,1,1)
axes.scatter(df['평균'],df['강수량'])

# %%
# 산점도 - 습도 
scatter_plot = plt.figure()
axes = scatter_plot.add_subplot(1,1,1)
axes.scatter(df['평균'],df['습도'])

# %%
# 산점도 - 체감온도
scatter_plot = plt.figure()
axes = scatter_plot.add_subplot(1,1,1)
axes.scatter(df['평균'],df['체감온도'])

# %%
# 산점도 - 이슬점 온도 
scatter_plot = plt.figure()
axes = scatter_plot.add_subplot(1,1,1)
axes.scatter(df['평균'],df['이슬점온도'])

# %%
# 산점도 - 현재기온
scatter_plot = plt.figure()
axes = scatter_plot.add_subplot(1,1,1)
axes.scatter(df['평균'],df['현재기온'])

# %% [markdown]
# # 상관계수 _ 원핫

# %%
df = pd.read_csv('./data/maindata.csv', encoding='utf-8')
df1 = pd.read_csv('./data/typhoon.csv', encoding='euc-kr')
df1 = df1.iloc[:,:3]

# %%
df.태풍.replace('o',4000,inplace= True)

# %%
df.태풍.replace('x',0,inplace= True)

# %%
# 중복값 확인 
# df.태풍.duplicated()
df.태풍.value_counts()
# Out:
# 0       1092
# 4000      96
# Name: 태풍, dtype: int64

# %%
# 결측치
df.fillna(0)
# Out:
#               날짜    평균    평년 현재일기  현재기온  이슬점온도  체감온도   강수량    습도   풍향    풍속  \
# 0     2015-01-02  1287  1561    -   2.1  -15.4  -2.3   0.0  26.0   북서  17.6
# 1     2015-01-05  1287  1449    -  10.4   -3.3  10.4   0.0  38.0  서북서   2.9
# 2     2015-01-06  1303  1432    -   9.1  -16.2   6.7  11.5  15.0   북서  15.8
# 3     2015-01-07  1277  1411    -   2.5  -28.5  -1.6   0.0   8.0   북서  16.9
# 4     2015-01-08  1352  1407    -   3.3  -19.4  -0.1   0.0  17.0   북서  13.7
# 5     2015-01-09  1333  1403    -   5.1  -12.4   1.6   0.0  27.0   북서  16.6
# 6     2015-01-12  1329  1352    -   4.9  -14.0   2.0   0.0  24.0  서북서  13.0
# 7     2015-01-13  1329  1340    -   9.1   -8.9   7.7   0.0  27.0  서남서   9.0
# 8     2015-01-14  1329  1326    -   5.3   -1.4   3.9   0.5  62.0  서북서   6.5
# 9     2015-01-15  1262  1321    -   9.3   -1.4   6.6   0.5  47.0   북서  18.7
# 10    2015-01-16  1258  1314    -   8.5   -5.3   5.7   0.0  37.0   북서  18.0
# ...

# %%
df = pd.get_dummies(df, columns=['태풍'], prefix='tor')

# %%
#  원핫 
# 태풍 =>'tor_o' 'tor_x'
heatmap_data  = df[['평균','현재기온', '이슬점온도', '체감온도', '강수량', '습도',
       '풍속', '해면기압', 'tor_o', 'tor_x']]

colormap = plt.cm.RdBu 
plt.figure(figsize=(14, 15))
plt.title('test', y=1.05, size=15)

sns.heatmap(heatmap_data.astype(float).corr(), linewidths=0.1, vmax=1.0,
           square=True, cmap=colormap, linecolor='white', annot=True, annot_kws={"size": 16})

# %% [markdown]
# # 무시

# %%
def get_month(year,month):
    
#     if month <10 : 
#         month = str(month) 
#         month = '0'+ month
#     elif month >= 10:
#         month = str(month)
            
    li_year = [ i[0] for i in main_data.날짜.str.split('-') ]
    li_month = [ i[1] for i in main_data.날짜.str.split('-') ]

    idx = list()

    for i in range(len(li_year)):
        if li_year[i] == str(year):
            if li_month[i] == month:
                idx.append(i)
    
    each_ye_mon = main_data.iloc[idx]
#     # 평균
#     each_mon_mean = each_ye_mon.mean().평균
#     print(each_mon_mean)
    
    return idx

# %%
def get_month_grp(year,month):
    
    if month <10 : 
        month = str(month) 
        month = '0'+ month
    elif month >= 10:
        month = str(month)
            
    li_year = [ i[0] for i in df.날짜.str.split('-') ]
    li_month = [ i[1] for i in df.날짜.str.split('-') ]

    idx = list()

    for i in range(len(li_year)):
        if li_year[i] == str(year):
            if li_month[i] == month:
                idx.append(i)
    
    each_ye_mon = df.iloc[idx]
    grp = plt.plot(df.날짜[idx],df.평균[idx])
#     # 평균
#     each_mon_mean = each_ye_mon.mean().평균
#     print(each_mon_mean)
    
    return grp

# %%
get_month_grp(2017,1)

# %%
def get_year(year):
    
    li_year = [ i[0] for i in main_data.날짜.str.split('-') ]
#     li_month = [ i[1] for i in main_data.날짜.str.split('-') ]

    li = main_data.shape[0]
    idx = list()

    for i in range(li):
        if li_year[i] == str(year):
            idx.append(i)
    #         if li_month[i] == "01":
    #             idx.append(i)

    each_year = main_data.iloc[idx]
#     print(each_year)


    # typhoon = idx.태풍[main_data.태풍 == 'o']
    # typhoon_date = idx.날짜
    
    return each_year

# %%
# 무시 
heatmap_data  = df[['평균', '평년','현재기온', '이슬점온도', '체감온도', '강수량', '습도',
       '풍속', '해면기압', '태풍']]

colormap = plt.cm.RdBu 
plt.figure(figsize=(14, 15))
plt.title('test', y=1.05, size=15)

sns.heatmap(heatmap_data.astype(float).corr(), linewidths=0.1, vmax=1.0,
           square=True, cmap=colormap, linecolor='white', annot=True, annot_kws={"size": 16})

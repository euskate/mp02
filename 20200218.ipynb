# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
m_data = pd.read_csv('./data/maindata.csv')

# %%
m_data
# Out:
#               날짜    평균    평년 현재일기  현재기온  이슬점온도  체감온도   강수량    습도   풍향    풍속  \
# 0     2015-01-02  1287  1561    -   2.1  -15.4  -2.3   0.0  26.0   북서  17.6
# 1     2015-01-05  1287  1449    -  10.4   -3.3  10.4   0.0  38.0  서북서   2.9
# 2     2015-01-06  1303  1432    -   9.1  -16.2   6.7  11.5  15.0   북서  15.8
# 3     2015-01-07  1277  1411    -   2.5  -28.5  -1.6   0.0   8.0   북서  16.9
# 4     2015-01-08  1352  1407    -   3.3  -19.4  -0.1   0.0  17.0   북서  13.7
# ...          ...   ...   ...  ...   ...    ...   ...   ...   ...  ...   ...
# 1183  2019-12-24  3073  1618    -  10.9   -0.5   9.2   0.0  45.0  서북서  13.3
# 1184  2019-12-26  3068  1596    -   6.1    0.6   3.0   0.0  68.0   북서  15.8
# 1185  2019-12-27  3022  1582    -   8.1  -12.3   5.4   0.0  22.0   북서  16.2
# 1186  2019-12-30  2987  1480    -  13.3    7.5  12.5   1.0  68.0   북서  10.4
# 1187  2019-12-31  3023  1473    -   2.5  -18.2  -1.9   0.0  20.0  서북서  18.7
#
#         해면기압 태풍
# 0     1021.4  x
# 1     1017.9  x
# ...

# %%
# 변수 설정
price = m_data.iloc[:,1:2]
tp = m_data.iloc[:,-1]
date = m_data.iloc[:,0]
df = m_data.iloc[:,]

# %%
corr = m_data.corr(method='pearson')
corr
# Out:
#              평균        평년      현재기온     이슬점온도      체감온도       강수량        습도  \
# 평균     1.000000  0.134773  0.244926  0.302058  0.197223  0.065621  0.224019
# 평년     0.134773  1.000000  0.632192  0.600628  0.522296  0.039035  0.295305
# 현재기온   0.244926  0.632192  1.000000  0.863388  0.880677  0.013277  0.319428
# 이슬점온도  0.302058  0.600628  0.863388  1.000000  0.823637  0.179032  0.740458
# 체감온도   0.197223  0.522296  0.880677  0.823637  1.000000  0.086758  0.416540
# 강수량    0.065621  0.039035  0.013277  0.179032  0.086758  1.000000  0.376017
# 습도     0.224019  0.295305  0.319428  0.740458  0.416540  0.376017  1.000000
# 풍속    -0.102537 -0.198813 -0.171850 -0.308782 -0.125486 -0.077262 -0.365190
# 해면기압  -0.144320 -0.405570 -0.684831 -0.714997 -0.742590 -0.230215 -0.475649
#
#              풍속      해면기압
# 평균    -0.102537 -0.144320
# 평년    -0.198813 -0.405570
# 현재기온  -0.171850 -0.684831
# 이슬점온도 -0.308782 -0.714997
# 체감온도  -0.125486 -0.742590
# 강수량   -0.077262 -0.230215
# ...

# %%
ax = plt.subplots()
ax = sns.distplot(m_data['평균'], kde=True) 
ax.set_title('EFFECT') 
ax.set_xlabel('TP') 
ax.set_ylabel('PRICE')
# Out:
# Text(0, 0.5, 'PRICE')

# %%
df.head(2)
df1 = df.loc[0:100]

# %%
df = m_data.iloc[:,0:2]
df1 = df.loc[0:300]

print(df1.iloc[0,[0]])
print(df1.iloc[-1,[0]])

plt.rcParams['figure.figsize'] = [40,6]

g = sns.catplot(x="날짜",y="평균",data=df1,kind="bar", height = 6 , palette = "muted")
g.despine(left=True)
g = g.set_ylabels("10대 잡지류")
# Out:
# 날짜    2015-01-02
# Name: 0, dtype: object
# 날짜    2016-03-22
# Name: 300, dtype: object

# %%
a = book_rate[book_rate.소분류 == "잡지류"]

g = sns.factorplot(x="연도",y="10대",data=a,kind="bar", size = 6 , 
palette = "muted")
g.despine(left=True)
g = g.set_ylabels("10대 잡지류")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-20a2615e5590> in <module>
# ----> 1 a = book_rate[book_rate.소분류 == "잡지류"]
#       2
#       3 g = sns.factorplot(x="연도",y="10대",data=a,kind="bar", size = 6 ,
#       4 palette = "muted")
#       5 g.despine(left=True)
#
# NameError: name 'book_rate' is not defined

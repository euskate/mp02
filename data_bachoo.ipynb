# %%
import pandas as pd
import os

# 폴더명 이름 'data_{name}'
name = 'apple'

# 파일 목록 가져오기
files = os.listdir(f'./data/data_{name}')

df_result = pd.DataFrame(columns=[0, 1, 'year', 'month', 'day'])

# %%
print(files)
# Out:
# ['2015-01-01_400411.xlsx', '2015-04-01_400411.xlsx', '2015-07-01_400411.xlsx', '2015-10-01_400411.xlsx', '2016-01-01_400411.xlsx', '2016-04-01_400411.xlsx', '2016-07-01_400411.xlsx', '2016-10-01_400411.xlsx', '2017-01-01_400411.xlsx', '2017-04-01_400411.xlsx', '2017-07-01_400411.xlsx', '2017-10-01_400411.xlsx', '2018-01-01_400411.xlsx', '2018-04-01_400411.xlsx', '2018-07-01_400411.xlsx', '2018-10-01_400411.xlsx', '2019-01-01_400411.xlsx', '2019-04-01_400411.xlsx', '2019-07-01_400411.xlsx', '2019-10-01_400411.xlsx']

# %%
for file in files:
    # 엑셀 데이터 프레임 만들기
    df = pd.read_excel(f'./data/data_{name}/{file}', nrows=2)
    # 뒤집기
    df = df.T
    # 필요없는 데이터 삭제
    df.drop(index=df.iloc[:3].index, inplace=True)
    # 파일명에서 연도 가져오기
    year = file[:4]
    # 인덱스 리셋하기
    df = df.reset_index()
    # 연,월,일 설정
    df['year'] = year
    df['month'] = df['index'].dt.month
    df['day'] = df['index'].dt.day
    # index 삭제
    del df['index']
    df_result = pd.concat([df_result, df])

# %%
df_result
# Out:
#          0       1  year month day
# 0   21,350  22,826  2015     1   5
# 1   21,717  22,882  2015     1   6
# 2   21,944  22,949  2015     1   7
# 3   21,442  22,809  2015     1   8
# 4   21,476  22,827  2015     1   9
# ..     ...     ...   ...   ...  ..
# 37  18,135  19,021  2019    12  24
# 38  18,293  19,055  2019    12  26
# 39  18,293  19,115  2019    12  27
# 40  18,328  19,290  2019    12  30
# 41  18,328  19,119  2019    12  31
#
# [1032 rows x 5 columns]

# %%
df_result.dtypes
# Out:
# 0        object
# 1        object
# year     object
# month    object
# day      object
# dtype: object

# %%
# 컬럼명 변경
df_result.rename(columns={0:'평균', 1:'평년'}, inplace=True)

# %%
df_result
# Out:
#         평균      평년  year month day
# 0   21,350  22,826  2015     1   5
# 1   21,717  22,882  2015     1   6
# 2   21,944  22,949  2015     1   7
# 3   21,442  22,809  2015     1   8
# 4   21,476  22,827  2015     1   9
# ..     ...     ...   ...   ...  ..
# 37  18,135  19,021  2019    12  24
# 38  18,293  19,055  2019    12  26
# 39  18,293  19,115  2019    12  27
# 40  18,328  19,290  2019    12  30
# 41  18,328  19,119  2019    12  31
#
# [1032 rows x 5 columns]

# %%
df_result.year = df_result.year.astype(int)
df_result.month = df_result.month.astype(int)
df_result.day = df_result.day.astype(int)
df_result.dtypes
# Out:
# 0        object
# 1        object
# year      int32
# month     int32
# day       int32
# dtype: object

# %%
# 컬럼 타입 변경
df_result.iloc[:,2:] = df_result.iloc[:,2:].apply(pd.to_numeric)
df_result.dtypes
# Out:
# 0        object
# 1        object
# year     object
# month    object
# day      object
# dtype: object

# %%
df.year.unique()
# Out:
# array(['2019'], dtype=object)

# %%
df_result.day.unique()
# Out:
# array([ 2,  5,  6,  7,  8,  9, 12, 13, 14, 15, 16, 19, 20, 21, 22, 23, 26,
#        27, 28, 29, 30,  3,  4, 10, 11, 17, 24, 25, 18, 31,  1],
#       dtype=int64)

# %%
# 날짜 컬럼 만들기
df_result['date'] = pd.to_datetime(df_result[['year','month','day']])

# %%
# # 컬럼 순서 조정
df_result = pd.DataFrame(df_result, columns=['date', '평균', '평년'])

# %%
df_result
# Out:
#          date      평균      평년
# 0  2015-01-05  21,350  22,826
# 1  2015-01-06  21,717  22,882
# 2  2015-01-07  21,944  22,949
# 3  2015-01-08  21,442  22,809
# 4  2015-01-09  21,476  22,827
# ..        ...     ...     ...
# 37 2019-12-24  18,135  19,021
# 38 2019-12-26  18,293  19,055
# 39 2019-12-27  18,293  19,115
# 40 2019-12-30  18,328  19,290
# 41 2019-12-31  18,328  19,119
#
# [1032 rows x 3 columns]

# %%
df_result.dtypes
# Out:
# date    datetime64[ns]
# 평균              object
# 평년              object
# dtype: object

# %%
df_result['평년'].unique()
# Out:
# array(['22,826', '22,882', '22,949', '22,809', '22,827', '23,395',
#        '23,518', '23,797', '23,878', '23,902', '24,812', '24,858',
#        '25,094', '25,114', '24,987', '24,844', '24,561', '24,634',
#        '24,717', '24,735', '24,578', '24,659', '24,537', '24,682',
#        '24,534', '24,607', '24,508', '24,442', '24,186', '24,154',
#        '23,726', '23,752', '23,779', '23,674', '23,785', '23,671',
#        '23,555', '23,497', '23,546', '23,498', '23,585', '23,252',
#        '23,492', '23,465', '23,437', '23,576', '23,868', '23,663',
#        '23,636', '23,577', '23,081', '22,986', '23,085', '23,156',
#        '23,248', '23,544', '23,677', '23,787', '24,098', '24,194',
#        '24,190', '23,880', '23,711', '23,302', '23,094', '23,035',
#        '23,133', '23,361', '24,684', '24,770', '24,292', '24,199',
#        '24,311', '24,126', '24,155', '24,166', '24,351', '24,618',
#        '24,687', '24,722', '24,761', '24,848', '24,943', '25,013',
# ...

# %%
df_result['평년'] = df_result['평년'].str.replace(',', '').str.replace('-','0').astype(int)

# %%
# 데이터 타입 변경
df_result['평균'] = pd.to_numeric(df_result['평균'].str.replace(',', ''))
# df_result['평년'] = df_result['평년'].str.replace(',', '').str.replace('-','').astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-d1b69cf25642> in <module>
#       1 # 데이터 타입 변경
# ----> 2 df_result['평균'] = pd.to_numeric(df_result['평균'].str.replace(',', ''))
#       3 # df_result['평년'] = df_result['평년'].str.replace(',', '').str.replace('-','').astype(int)
#       4 df_result['평균']
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5173             or name in self._accessors
#    5174         ):
# -> 5175             return object.__getattribute__(self, name)
#    5176         else:
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     173             # we're accessing the attribute of the class, i.e., Dataset.geo
#     174             return self._accessor
# ...

# %%
df_result['평년']
# Out:
# 0     22826
# 1     22882
# 2     22949
# 3     22809
# 4     22827
#       ...
# 37    19021
# 38    19055
# 39    19115
# 40    19290
# 41    19119
# Name: 평년, Length: 1032, dtype: object

# %%
df_result['평년'] = pd.to_numeric(df_result['평년'].str.replace(',', ''), errors='coerce', downcast='int' )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-77293a9faae8> in <module>
# ----> 1 df_result['평년'] = pd.to_numeric(df_result['평년'].str.replace(',', ''), errors='coerce', downcast='int' )
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5173             or name in self._accessors
#    5174         ):
# -> 5175             return object.__getattribute__(self, name)
#    5176         else:
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     173             # we're accessing the attribute of the class, i.e., Dataset.geo
#     174             return self._accessor
# --> 175         accessor_obj = self._accessor(obj)
#     176         # Replace the property with the accessor object. Inspired by:
# ...

# %%
df_result['평년'] = pd.to_numeric(df_result['평년'], errors='coerce', downcast='int' )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-b3b6b70e43c3> in <module>
# ----> 1 df_result['평년'] = pd.to_numeric(df_result['평년'], errors='coerce', downcast='int' )
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     109     """
#     110     if downcast not in (None, "integer", "signed", "unsigned", "float"):
# --> 111         raise ValueError("invalid downcasting method provided")
#     112
#     113     if errors not in ("ignore", "raise", "coerce"):
#
# ValueError: invalid downcasting method provided

# %%
df_result.dtypes
# Out:
# date    datetime64[ns]
# 평균               int64
# 평년             float64
# dtype: object

# %%
df_result['평년'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-bf60b6864c25> in <module>
# ----> 1 df_result['평년'].astype(int)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5880             # else, only a single dtype is given
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
#    5884             return self._constructor(new_data).__finalize__(self)
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
#     583     def convert(self, **kwargs):
#
# ...

# %%
# 컬럼명 2차 변경
df_result.rename(columns={'평균':f'avg_{name}', '평년':f'avgY_{name}'}, inplace=True)

# 확인
print(df_result.columns)
print(df_result.head())
print(df_result.shape)
print(df_result.dtypes)

# CSV 파일로 만들기
df_result.to_csv('./data/result_{name}.csv', encoding="utf-8", index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-e3165e2046a3> in <module>
#       3
#       4 # 데이터 타입 변경
# ----> 5 df_result['평균'] = df_result['평균'].str.replace(',', '').astype(int)
#       6 df_result['평년'] = df_result['평년'].str.replace(',', '').astype(int)
#       7
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5173             or name in self._accessors
#    5174         ):
# -> 5175             return object.__getattribute__(self, name)
#    5176         else:
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     173             # we're accessing the attribute of the class, i.e., Dataset.geo
#     174             return self._accessor
# --> 175         accessor_obj = self._accessor(obj)
# ...

# %%
import pandas as pd

# %%
Path = './data/지역별도서관현황_2017.csv'
Location_lib = pd.read_csv( Path, header=1, encoding='euc-kr', engine='python')
Location_lib.head()
# Out:
#   지역(1)  도서관 수(관)  총 도서(인쇄) 수(권)  총 비도서 수(점)  총 연속간행물 수(종)  총 전자자료 수(종)  \
# 0    전국      1010       98823835     3821681        138403     14537798
# 1    서울       147       12583120      515455         24633      8555650
# 2    부산        40        5124311      259239         10545       395112
# 3    대구        35        3892030      175997          6468       272603
# 4    인천        47        4017969      184716          5080       195009
#
#    1관당 평균 도서(인쇄) 수(권)  1관당 비도서 수(점)  1관당 연속간행물 수(종)  1관당 전자자료 수(종)  \
# 0               97845          3784             137          14394
# 1               85599          3506             168          58202
# 2              128108          6481             264           9878
# 3              111201          5028             185           7789
# 4               85489          3930             108           4149
#
#         ...         총 연속간행물 수(종).1  총 전자자료 수(종).1  1관당 평균 도서(인쇄) 수(권).1  \
# ...

# %%
print(Location_lib.columns)
# Out:
# Index(['지역(1)', '도서관 수(관)', '총 도서(인쇄) 수(권)', '총 비도서 수(점)', '총 연속간행물 수(종)',
#        '총 전자자료 수(종)', '1관당 평균 도서(인쇄) 수(권)', '1관당 비도서 수(점)', '1관당 연속간행물 수(종)',
#        '1관당 전자자료 수(종)', '총 방문자 수(명)', '1관당 방문자 수(명)', '연간 이용자 수(명)',
#        '연간 대출 도서 수(권)', '도서관 수(관).1', '총 도서(인쇄) 수(권).1', '총 비도서 수(점).1',
#        '총 연속간행물 수(종).1', '총 전자자료 수(종).1', '1관당 평균 도서(인쇄) 수(권).1',
#        '1관당 비도서 수(점).1', '1관당 연속간행물 수(종).1', '1관당 전자자료 수(종).1', '총 방문자 수(명).1',
#        '1관당 방문자 수(명).1', '연간 이용자 수(명).1', '연간 대출 도서 수(권).1'],
#       dtype='object')

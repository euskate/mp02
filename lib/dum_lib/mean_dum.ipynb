# %%
import pandas as pd 
from pandas import DataFrame as df 
# s넘파이
import numpy as np
import datetime

# %%
result_df = pd.read_csv('./data/result_df.csv', encoding='utf-8')
df_year = df(columns=['월','년','평년','평균'])
result_df.shape
# Out:
# (1188, 3)

# %%
# df_year

# %%
li_year = [ i[0] for i in result_df.date.str.split('-') ]
li_month = [ i[1] for i in result_df.date.str.split('-') ]

# %%
type({result_df.shape[0]})
type(li_year)  



len(li_year)
# Out:
# list

# %%
li = result_df.shape[0]
idx = list()

for i in range(li):
    if li_year[i] == "2017":
        if li_month[i] == "01":
            idx.append(i)
            
each_ye_mon = result_df.iloc[idx]
each_mon_mean = each_ye_mon.mean().평균
print(each_mon_mean)
# Out:
# 2796.65

# %%
df_year['월'] = [s.split('-')[1]for s in result_df['date']]

# %%
# for s in result_df['date']:
#     print(s.split('-')[0].)
df_year['월'] = [s.split('-')[0]for s in result_df['date']] 
# drop_duplicates() 중복값 유일값만 남기고 전부 삭제 
df_year = df_year.drop_duplicates()

# %%
df_year
# Out:
#         월    년   평년   평균
# 0    2015  NaN  NaN  NaN
# 248  2016  NaN  NaN  NaN
# 494  2017  NaN  NaN  NaN
# 737  2018  NaN  NaN  NaN
# 942  2019  NaN  NaN  NaN

# %%
df_year
# Out:
#        월    년   평년   평균    연도
# 0    NaN  NaN  NaN  NaN  2015
# 248  NaN  NaN  NaN  NaN  2016
# 494  NaN  NaN  NaN  NaN  2017
# 737  NaN  NaN  NaN  NaN  2018
# 942  NaN  NaN  NaN  NaN  2019

# %%
# Out:
# Empty DataFrame
# Columns: [월, 년, 평년, 평균]
# Index: []

# %%
get_m(2015,'01')
df_year['']
# Out:
# 1268.2857142857142

# %%
def get_m(year,month):
    
    li_year = [ i[0] for i in result_df.date.str.split('-') ]
    li_month = [ i[1] for i in result_df.date.str.split('-') ]

    idx = list()

    for i in range(len(li)):
        if li_year[i] == str(year):
            if li_month[i] == month:
                idx.append(i)
    
    each_ye_mon = result_df.iloc[idx]
    # 평균
    each_mon_mean = each_ye_mon.mean().평균
    
    return each_mon_mean

# %%
li_year = [ i[0] for i in result_df.date.str.split('-') ]
li_month = [ i[1] for i in result_df.date.str.split('-') ]


idx = list()

for i in range(len(li)):
    if li_year[i] == "2017":
        if li_month[i] == "11":
            idx.append(i)
print(idx)
# Out:
# [696, 697, 698, 699, 700, 701, 702, 703, 704, 705, 706, 707, 708, 709, 710, 711, 712, 713, 714, 715, 716, 717]

# %%
each_ye_mon = result_df.iloc[idx]
each_mon_mean = each_ye_mon.mean().평균
each_mon_mean
# Out:
# 2796.65

# %%
for year in range(2015,2020):
    print(year)
    for i in range(1,13) :
        if i <10 : 
            i = str(i) 
            i = '0'+i
        elif i >= 10:
            i = str(i)
        print(i)
# Out:
# 2015
# 01
# 02
# 03
# 04
# 05
# 06
# 07
# 08
# 09
# 10
# 11
# 12
# 2016
# 01
# 02
# 03
# 04
# 05
# 06
# 07
# 08
# 09
# 10
# 11
# 12
# 2017
# 01
# 02
# 03
# 04
# 05
# 06
# 07
# 08
# 09
# 10
# 11
# 12
# 2018
# 01
# 02
# 03
# 04
# 05
# 06
# 07
# 08
# 09
# 10
# 11
# 12
# 2019
# 01
# 02
# 03
# 04
# 05
# 06
# 07
# 08
# 09
# 10
# 11
# 12

# %%
# while True:
    
#     for year in range(2015,2020):
# #         print(year)
#         for i in range(1,13) :
#             if i <10 : 
#                 i = str(i) 
#                 i = '0'+i
#             elif i >= 10:
#                 i = str(i)
#             print(i)
    

# break
# Out:
# 2015
# 01
# 02
# 03
# 04
# 05
# 06
# 07
# 08
# 09
# 10
# 11
# 12
# 2016
# 01
# 02
# 03
# 04
# 05
# 06
# 07
# 08
# 09
# 10
# 11
# 12
# 2017
# 01
# 02
# 03
# 04
# 05
# 06
# 07
# 08
# 09
# 10
# 11
# 12
# 2018
# 01
# 02
# 03
# 04
# 05
# 06
# 07
# 08
# 09
# 10
# 11
# 12
# 2019
# 01
# 02
# 03
# 04
# 05
# 06
# 07
# 08
# 09
# 10
# 11
# 12
# 2015
# 01
# 02
# 03
# 04
# 05
# 06
# 07
# 08
# 09
# 10
# 11
# 12
# 2016
# 01
# 02
# 03
# 04
# 05
# 06
# 07
# 08
# 09
# 10
# 11
# 12
# 2017
# 01
# 02
# 03
# 04
# 05
# 06
# 07
# 08
# 09
# 10
# 11
# 12
# 2018
# 01
# 02
# 03
# 04
# 05
# 06
# 07
# 08
# 09
# 10
# 11
# 12
# 2019
# 01
# 02
# 03
# 04
# 05
# 06
# 07
# 08
# 09
# 10
# 11
# 12
# 2015
# 01
# 02
# 03
# 04
# 05
# 06
# 07
# 08
# 09
# 10
# 11
# 12
# 2016
# 01
# 02
# 03
# 04
# 05
# 06
# 07
# 08
# 09
# 10
# 11
# 12
# 2017
# 01
# 02
# 03
# 04
# 05
# 06
# 07
# 08
# 09
# 10
# 11
# 12
# 2018
# 01
# 02
# 03
# 04
# 05
# 06
# 07
# 08
# 09
# 10
# 11
# 12
# 2019
# 01
# 02
# 03
# 04
# 05
# 06
# 07
# 08
# 09
# 10
# 11
# ...

# %%
def get_m(year,month):
    
    li_year = [ i[0] for i in result_df.date.str.split('-') ]
    li_month = [ i[1] for i in result_df.date.str.split('-') ]

    idx = list()

    for i in range(len(li_year)):
        if li_year[i] == str(year):
            if li_month[i] == month:
                idx.append(i)
    
    each_ye_mon = result_df.iloc[idx]
    # 평균
    each_mon_mean = each_ye_mon.mean().평균
    print(each_mon_mean)
    
    return each_mon_mean

# %%
a = list()
for year in range(2015,2020):
#     print(type(year))
    for i in range(1,13) :
        if i <10 : 
            i = str(i) 
            i = '0'+i
        elif i >= 10:
            i = str(i)
#         print(i)
#         print(type(i))
        print("=== " + str(year) + '-' + i + "=========")
        get_m(year,i)
        
        
# get_m(year,i)
# Out:
# === 2015.01=========
# 1268.2857142857142
# === 2015.02=========
# 1233.8235294117646
# === 2015.03=========
# 1271.1818181818182
# === 2015.04=========
# 1322.3636363636363
# === 2015.05=========
# 1366.2222222222222
# === 2015.06=========
# 1811.3181818181818
# === 2015.07=========
# 2196.1304347826085
# === 2015.08=========
# 1932.15
# === 2015.09=========
# 1661.7
# === 2015.10=========
# 1412.142857142857
# === 2015.11=========
# 1353.0
# === 2015.12=========
# 1361.3809523809523
# === 2016.01=========
# 1376.65
# === 2016.02=========
# 1848.388888888889
# === 2016.03=========
# 1883.0454545454545
# === 2016.04=========
# 2058.95
# === 2016.05=========
# 2176.7
# === 2016.06=========
# 1821.3809523809523
# === 2016.07=========
# 1794.3809523809523
# === 2016.08=========
# 1968.1818181818182
# === 2016.09=========
# 2944.5789473684213
# === 2016.10=========
# 3346.7
# === 2016.11=========
# 2531.318181818182
# === 2016.12=========
# 2710.3333333333335
# === 2017.01=========
# ...

# %%
c_get = get_m(2017,'01')

# %%
result_df.iloc[c_get].mean().평균
# Out:
# 2796.65

# %%
# result_df['date'].loc[0].split(" ")[0].split('-')
# for m in result_df['date']:
#     print(m.split(' ')[0].split('-')[1])
# Out:
#   File "<ipython-input-169-33a79d3cc2d7>", line 2
#     #     print(m.split(' ')[0].split('-')[1])
#                                               ^
# SyntaxError: unexpected EOF while parsing

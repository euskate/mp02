# %%
import pandas as pd 
import numpy as np
import time

# %%
result_df = pd.read_csv('./data/result_df.csv', encoding='utf-8') 
result_df
# Out:
#          평균     평년  year  month  day
# 0     1,287  1,561  2015      1    2
# 1     1,287  1,449  2015      1    5
# 2     1,303  1,432  2015      1    6
# 3     1,277  1,411  2015      1    7
# 4     1,352  1,407  2015      1    8
# 5     1,333  1,403  2015      1    9
# 6     1,329  1,352  2015      1   12
# 7     1,329  1,340  2015      1   13
# 8     1,329  1,326  2015      1   14
# 9     1,262  1,321  2015      1   15
# 10    1,258  1,314  2015      1   16
# 11    1,253  1,268  2015      1   19
# 12    1,262  1,254  2015      1   20
# 13    1,254  1,239  2015      1   21
# 14    1,233  1,222  2015      1   22
# 15    1,241  1,216  2015      1   23
# 16    1,228  1,221  2015      1   26
# 17    1,212  1,231  2015      1   27
# 18    1,199  1,241  2015      1   28
# 19    1,203  1,239  2015      1   29
# 20    1,203  1,251  2015      1   30
# 21    1,210  1,241  2015      2    2
# 22    1,214  1,238  2015      2    3
# 23    1,213  1,238  2015      2    4
# ...

# %%
moo = pd.read_excel('./data/2015_01_03.xlsx', encoding= 'utf-8')
moo
# Out:
#      구분 Unnamed: 1 Unnamed: 2 2020-01-02 00:00:00 2020-01-05 00:00:00  \
# 0    평균        NaN        NaN               1,287               1,287
# 1    평년        NaN        NaN               1,561               1,449
# 2    서울         경동         가을               1,500               1,500
# 3   NaN        NaN         월동               1,500               1,500
# 4   NaN        복조리         가을               1,500               1,500
# 5   NaN        NaN         월동               1,500               1,500
# 6   NaN        영등포         가을               2,000               2,000
# 7   NaN        NaN         월동               1,500               1,500
# 8   NaN       A-유통         월동               1,350               1,350
# 9   NaN       B-유통         월동               1,180               1,180
# 10  NaN       C-유통         월동               1,280               1,280
# 11  NaN       E-유통         월동               1,000               1,000
# ...

# %%
moo.fillna(0)

# %%
moo.T
# Out:
#                         0      1      2      3      4      5      6      7   \
# 구분                      평균     평년     서울    NaN    NaN    NaN    NaN    NaN
# Unnamed: 1             NaN    NaN     경동    NaN    복조리    NaN    영등포    NaN
# Unnamed: 2             NaN    NaN     가을     월동     가을     월동     가을     월동
# 2020-01-02 00:00:00  1,287  1,561  1,500  1,500  1,500  1,500  2,000  1,500
# 2020-01-05 00:00:00  1,287  1,449  1,500  1,500  1,500  1,500  2,000  1,500
# 2020-01-06 00:00:00  1,303  1,432  1,500  1,500  1,500  1,500  2,000  1,500
# 2020-01-07 00:00:00  1,277  1,411      -  1,500      -  1,500      -  1,500
# 2020-01-08 00:00:00  1,352  1,407      -  1,500      -  1,500      -  1,500
# 2020-01-09 00:00:00  1,333  1,403      -  1,500      -  1,500      -  1,500
# 2020-01-12 00:00:00  1,329  1,352      -  1,500      -  1,500      -  1,500
# 2020-01-13 00:00:00  1,329  1,340      -  1,500      -  1,500      -  1,500
# ...

# %%
moo.구분[51:]
# Out:
# 51     제주
# 52    NaN
# 53    NaN
# Name: 구분, dtype: object

# %%
moo.구분.unique()
# Out:
# array(['평균', '평년', '서울', '부산', '대구', '인천', '광주', '대전', '울산', '수원', '의정부',
#        '춘천', '청주', '전주', '순천', '포항', '안동', '창원', '제주'], dtype=object)

# %%
# # 지역 (구분)
# moo.구분[2:13] = '서울' 
# moo.구분[13:17] = '부산' 
# moo.구분[17:21] = '대구' 
# moo.구분[21:24] = '인천' 
# moo.구분[24:27] = '광주' 
# moo.구분[27:31] = '대전' 
# moo.구분[31:33] = '울산' 
# moo.구분[33:36] = '수원' 
# moo.구분[37:39] = '춘천' 
# moo.구분[39:42] = '청주' 
# moo.구분[42:44] = '전주' 
# moo.구분[45:47] = '포항' 
# moo.구분[48:51] = '창원' 
# moo.구분[51:] = '제주'

# %%
# 삭제할 컬럼 선정 
dum_cols = moo.columns[1:3]
# 데이터 제거 
# 굳이 예외 처리를 하는 이유 => 
try:    
    moo.drop( dum_cols, inplace=True, axis=1 )
    print("columns 제거>>> \n", moo.head(2) )
except Exception as e:
    print('error => ',e) # 눈으로 확인이 가능하다
# Out:
# columns 제거>>>
#     구분 2020-01-02 00:00:00 2020-01-05 00:00:00 2020-01-06 00:00:00  \
# 0  평균               1,287               1,287               1,303
# 1  평년               1,561               1,449               1,432
#
#   2020-01-07 00:00:00 2020-01-08 00:00:00 2020-01-09 00:00:00  \
# 0               1,277               1,352               1,333
# 1               1,411               1,407               1,403
#
#   2020-01-12 00:00:00 2020-01-13 00:00:00 2020-01-14 00:00:00  \
# 0               1,329               1,329               1,329
# 1               1,352               1,340               1,326
#
#           ...         2020-03-18 00:00:00 2020-03-19 00:00:00  \
# 0         ...                       1,260               1,257
# 1         ...                       1,297               1,305
#
#   2020-03-20 00:00:00 2020-03-23 00:00:00 2020-03-24 00:00:00  \
# 0               1,239               1,261               1,261
# ...
